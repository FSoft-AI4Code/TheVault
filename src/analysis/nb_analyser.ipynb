# %% [markdown]
# # Overall Summary

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
language = 'Go'

# %%
df = pd.read_csv(f'/datadrive/2M_codeparrot/{str(language).lower()}/analysis_results.csv')

# %%
df.describe()
# Out:
#          #code_line  #docstring_line  #comment_line   #blank_line  \
# count  1.823276e+06     1.823276e+06  838083.000000  1.249729e+06
# mean   2.165361e+01     2.698024e+00       3.643533  4.610081e+00
# std    3.190569e+01     4.440515e+00       7.228335  6.421827e+00
# min    1.000000e+00     1.000000e+00       1.000000  1.000000e+00
# 25%    8.000000e+00     1.000000e+00       1.000000  1.000000e+00
# 50%    1.400000e+01     1.000000e+00       2.000000  3.000000e+00
# 75%    2.500000e+01     3.000000e+00       4.000000  5.000000e+00
# max    1.230500e+04     1.145000e+03    1433.000000  1.039000e+03
#
#         #code_token  #docstring_token  #comment_token     #attribute  \
# count  1.823276e+06      1.823276e+06   837989.000000  410746.000000
# mean   1.179495e+02      2.366024e+01       34.267854       2.675098
# std    2.501132e+02      4.058889e+01       64.682679       2.310647
# min    5.000000e+00      1.000000e+00        1.000000       1.000000
# ...

# %%
df.head()
# Out:
#                repo_path  #code_line  #docstring_line  #comment_line  \
# 0  richard-willowit/odoo          14                1            2.0
# 1  richard-willowit/odoo          21                1            NaN
# 2  richard-willowit/odoo          12                3            NaN
# 3  richard-willowit/odoo           6                1            NaN
# 4  richard-willowit/odoo          27                2           21.0
#
#    #blank_line  #code_token  #docstring_token  #comment_token  #attribute  \
# 0          NaN           94                 1            21.0         NaN
# 1          NaN           97                 1             NaN         NaN
# 2          NaN           69                40             NaN         NaN
# 3          NaN           36                13             NaN         NaN
# 4          1.0          200                29           213.0         NaN
#
#    #alpha_char  #digit_char  #special_char
# 0          4.0          NaN            NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1823276 entries, 0 to 1823275
# Data columns (total 12 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   repo_path         object
#  1   #code_line        int64
#  2   #docstring_line   int64
#  3   #comment_line     float64
#  4   #blank_line       float64
#  5   #code_token       int64
#  6   #docstring_token  int64
#  7   #comment_token    float64
#  8   #attribute        float64
#  9   #alpha_char       float64
#  10  #digit_char       float64
#  11  #special_char     float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 166.9+ MB

# %%
df.isna().sum()
# Out:
# repo_path           0
# #code_line          0
# #docstring_line     0
# #comment_line       0
# #blank_line         0
# #code_token         0
# #docstring_token    0
# #comment_token      0
# #attribute          0
# #alpha_char         0
# #digit_char         0
# #special_char       0
# dtype: int64

# %% [markdown]
# # Dataset Profiling

# %%
from ydata_profiling import ProfileReport
import numpy as np

# Sample 10.000 rows
# sample = df.sample(10000)

profile = ProfileReport(df, title=f"{language} Profiling Report", minimal=True)

# %%
profile.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
profile.to_file(f"./{language}_2M_codeparrot_summary.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
for idx, item in df.nsmallest(n=50, columns=['#len_code']).iterrows():
    print('===== Sample {} ====='.format(idx))
    print(item['code'])
# Out:
# ===== Sample 98894 =====
# namespace util {
#
# //void setLogging(const RunProfile& profile) {
# //  std::vector<std::pair<logging::LogModuleEnum,logging::LogLevelEnum> moduleLogLevels;
# //  for (int i = 0; i < logging::LogModuleEnum::NUM_ENUMS; i++) {
# //    moduleLogLevels.push_back(std::make_pair(
# //      logging::LogModuleEnum(i),
# //      profile.getLogLevel(module)
# //    ));
# //  setModuleLogLevels(moduleLogLevels);
# ////    logging::LogModuleEnum module(i);
# ////    logging::g_l_filter()->set_enabled(module, profile.getLogLevel(module));
# //  }
# //
# //  setLogTags(profile.getLogTags());
# //
# //}
#
# }
# ===== Sample 178578 =====
# namespace ACE_OS
# {
#
#
#
#   // = A set of wrappers for miscellaneous operations.
#
#
# }
# ===== Sample 477403 =====
# namespace Caneda
# {
# /*!
#  * \page CodingStylePage Caneda Coding Style
#  *
#  * \tableofcontents
#  *
#  * Extracted from Arora Coding Style. Feel free to edit to our needs.
#  *
# ...

# %%
df.nlargest(n=1000, columns=['#len_docstring'])
# Out:
#         Unnamed: 0                    repo_path  \
# 401869      401869               dickens/libusb
# 650611      650611                 kuym/openocd
# 324502      324502           BonexGu/Blik2D-SDK
# 584262      584262   iPodLinux/linux-2.6.7-ipod
# 14046        14046           Dabug123/owlCore64
# ...            ...                          ...
# 143298      143298    timothy-king/glpk-cut-log
# 176062      176062  pic32mcu/pic32accessory-iot
# 211401      211401       alexwinger/JAMMAPP2USB
# 308956      308956             mlaz/mynewt-core
# 370026      370026       csolg/hi35xx-buildroot
#
#                                                      code  \
# 401869  int usbi_io_init(struct libusb_context *ctx)\n...
# 650611  int usbi_io_init(struct libusb_context *ctx)\n...
# 324502  PIX *\npixOctreeColorQuant(PIX     *pixs,\n   ...
# 584262  int MoxaPortIsValid(int port)\n{\n\n\tif (moxa...
# 14046   static inline bool bfq_bfqq_must_not_expire(st...
# ...
